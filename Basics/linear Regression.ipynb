# %%
# Let's import the required packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.metrics import mean_absolute_error 
from sklearn.metrics import mean_squared_error

# %%
# Let's get Train Data
trainData = pd.read_csv('../Data/Linear regression/train.csv') 
trainData.fillna(0, inplace=True)
trainData
# Out:
#       x          y
# 0    24  21.549452
# 1    50  47.464463
# 2    15  17.218656
# 3    38  36.586398
# 4    87  87.288984
# ..   ..        ...
# 695  58  58.595006
# 696  93  94.625094
# 697  82  88.603770
# 698  66  63.648685
# 699  97  94.975266
#
# [700 rows x 2 columns]

# %%
# Let's get Test Data
testData = pd.read_csv('../Data/Linear regression/test.csv') 
# testData.fillna(0, inplace=True)
testData
# Out:
#       x          y
# 0    77  79.775152
# 1    21  23.177279
# 2    22  25.609262
# 3    20  17.857388
# 4    36  41.849864
# ..   ..        ...
# 295  71  68.545888
# 296  46  47.334876
# 297  55  54.090637
# 298  62  63.297171
# 299  47  52.459467
#
# [300 rows x 2 columns]

# %%
plt.scatter(trainData.x,trainData.y, color='black',marker='*')

# %%
linearReg = linear_model.LinearRegression()
linearReg.fit(trainData[['x']],trainData.y)
# Out:
# LinearRegression()

# %%
m = linearReg.coef_
c = linearReg.intercept_
print('coefficent:',m,'intercept:',c)
# Out:
# coefficent: [1.00077825] intercept: -0.12015553181322502

# %%
# Plot for test data
plt.scatter(testData.x,testData.y, color='black',marker='*')
Y_pred=linearReg.predict(testData[['x']])
plt.plot(testData.x, Y_pred,color="blue")

# %%
# Let's find mean square error and mean absolute error for test data
mse = mean_squared_error(Y_test,Y_pred)
mae = mean_absolute_error(Y_test,Y_pred)
print(" mean absolute error ",mae)
print("mean squared error ",mse)

# Calculate percentage errors
percentage_errors = (abs(Y_test-Y_pred) / Y_test) * 100

# Print percentage errors
print("Percentage Errors:", percentage_errors.mean())
# Out:
#  mean absolute error  2.415841458550141
# mean squared error  9.434852832251455
# Percentage Errors: 8.220112381495817
